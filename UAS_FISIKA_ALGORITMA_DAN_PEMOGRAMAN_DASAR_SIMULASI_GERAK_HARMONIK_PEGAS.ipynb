# %% [markdown]
# <a href="https://colab.research.google.com/github/2510631330014-dotcom/ALMALIA-RIZKI-YANI/blob/main/UAS_FISIKA_ALGORITMA_DAN_PEMOGRAMAN_DASAR_SIMULASI_GERAK_HARMONIK_PEGAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import math

print("=== SIMULASI GERAK HARMONIK PEGAS ===")
print("Program ini mensimulasikan gerak benda pada pegas (Hukum Hooke).")

k = float(input("Masukkan konstanta pegas k (N/m): "))
m = float(input("Masukkan massa beban m (kg): "))
A = float(input("Masukkan amplitudo awal A (meter): "))

omega = math.sqrt(k / m)

t = 0
dt = 0.05
t_max = 10

time_data = []
x_data = []

while t <= t_max:
    x = A * math.cos(omega * t)

    if abs(x) > A:
        print("Error: posisi benda melebihi batas amplitudo.")
        break

    time_data.append(t)
    x_data.append(x)

    print(f"t = {t:.2f} s | posisi x = {x:.3f} meter")

    t += dt

plt.plot(time_data, x_data)
plt.title("Simulasi Gerak Harmonik Pegas")
plt.xlabel("Waktu (s)")
plt.ylabel("Posisi (m)")
plt.grid(True)
plt.show()
# Out:
# === SIMULASI GERAK HARMONIK PEGAS ===
# Program ini mensimulasikan gerak benda pada pegas (Hukum Hooke).
# Masukkan konstanta pegas k (N/m): 20
# Masukkan massa beban m (kg): 1
# Masukkan amplitudo awal A (meter): 0.5
# t = 0.00 s | posisi x = 0.500 meter
# t = 0.05 s | posisi x = 0.488 meter
# t = 0.10 s | posisi x = 0.451 meter
# t = 0.15 s | posisi x = 0.392 meter
# t = 0.20 s | posisi x = 0.313 meter
# t = 0.25 s | posisi x = 0.219 meter
# t = 0.30 s | posisi x = 0.114 meter
# t = 0.35 s | posisi x = 0.003 meter
# t = 0.40 s | posisi x = -0.108 meter
# t = 0.45 s | posisi x = -0.214 meter
# t = 0.50 s | posisi x = -0.309 meter
# t = 0.55 s | posisi x = -0.388 meter
# t = 0.60 s | posisi x = -0.448 meter
# t = 0.65 s | posisi x = -0.486 meter
# t = 0.70 s | posisi x = -0.500 meter
# t = 0.75 s | posisi x = -0.489 meter
# t = 0.80 s | posisi x = -0.453 meter
# t = 0.85 s | posisi x = -0.395 meter
# t = 0.90 s | posisi x = -0.317 meter
# t = 0.95 s | posisi x = -0.224 meter
# t = 1.00 s | posisi x = -0.119 meter
# t = 1.05 s | posisi x = -0.008 meter
# t = 1.10 s | posisi x = 0.103 meter
# t = 1.15 s | posisi x = 0.209 meter
# t = 1.20 s | posisi x = 0.304 meter
# t = 1.25 s | posisi x = 0.385 meter
# t = 1.30 s | posisi x = 0.446 meter
# t = 1.35 s | posisi x = 0.485 meter
# t = 1.40 s | posisi x = 0.500 meter
# t = 1.45 s | posisi x = 0.490 meter
# t = 1.50 s | posisi x = 0.456 meter
# t = 1.55 s | posisi x = 0.398 meter
# t = 1.60 s | posisi x = 0.322 meter
# t = 1.65 s | posisi x = 0.229 meter
# t = 1.70 s | posisi x = 0.124 meter
# t = 1.75 s | posisi x = 0.014 meter
# t = 1.80 s | posisi x = -0.097 meter
# t = 1.85 s | posisi x = -0.204 meter
# t = 1.90 s | posisi x = -0.300 meter
# t = 1.95 s | posisi x = -0.381 meter
# t = 2.00 s | posisi x = -0.443 meter
# t = 2.05 s | posisi x = -0.484 meter
# t = 2.10 s | posisi x = -0.500 meter
# t = 2.15 s | posisi x = -0.491 meter
# t = 2.20 s | posisi x = -0.458 meter
# t = 2.25 s | posisi x = -0.402 meter
# t = 2.30 s | posisi x = -0.326 meter
# t = 2.35 s | posisi x = -0.234 meter
# t = 2.40 s | posisi x = -0.130 meter
# t = 2.45 s | posisi x = -0.019 meter
# t = 2.50 s | posisi x = 0.092 meter
# t = 2.55 s | posisi x = 0.199 meter
# t = 2.60 s | posisi x = 0.295 meter
# t = 2.65 s | posisi x = 0.377 meter
# t = 2.70 s | posisi x = 0.441 meter
# t = 2.75 s | posisi x = 0.482 meter
# t = 2.80 s | posisi x = 0.500 meter
# t = 2.85 s | posisi x = 0.492 meter
# t = 2.90 s | posisi x = 0.460 meter
# t = 2.95 s | posisi x = 0.405 meter
# t = 3.00 s | posisi x = 0.330 meter
# t = 3.05 s | posisi x = 0.238 meter
# t = 3.10 s | posisi x = 0.135 meter
# t = 3.15 s | posisi x = 0.025 meter
# t = 3.20 s | posisi x = -0.086 meter
# t = 3.25 s | posisi x = -0.193 meter
# t = 3.30 s | posisi x = -0.291 meter
# t = 3.35 s | posisi x = -0.374 meter
# t = 3.40 s | posisi x = -0.438 meter
# t = 3.45 s | posisi x = -0.481 meter
# t = 3.50 s | posisi x = -0.499 meter
# t = 3.55 s | posisi x = -0.493 meter
# t = 3.60 s | posisi x = -0.462 meter
# t = 3.65 s | posisi x = -0.408 meter
# t = 3.70 s | posisi x = -0.334 meter
# t = 3.75 s | posisi x = -0.243 meter
# t = 3.80 s | posisi x = -0.140 meter
# t = 3.85 s | posisi x = -0.030 meter
# t = 3.90 s | posisi x = 0.081 meter
# t = 3.95 s | posisi x = 0.188 meter
# t = 4.00 s | posisi x = 0.286 meter
# t = 4.05 s | posisi x = 0.370 meter
# t = 4.10 s | posisi x = 0.435 meter
# t = 4.15 s | posisi x = 0.479 meter
# t = 4.20 s | posisi x = 0.499 meter
# t = 4.25 s | posisi x = 0.494 meter
# t = 4.30 s | posisi x = 0.464 meter
# t = 4.35 s | posisi x = 0.411 meter
# t = 4.40 s | posisi x = 0.338 meter
# t = 4.45 s | posisi x = 0.248 meter
# t = 4.50 s | posisi x = 0.146 meter
# t = 4.55 s | posisi x = 0.036 meter
# t = 4.60 s | posisi x = -0.075 meter
# t = 4.65 s | posisi x = -0.183 meter
# t = 4.70 s | posisi x = -0.282 meter
# t = 4.75 s | posisi x = -0.366 meter
# t = 4.80 s | posisi x = -0.433 meter
# t = 4.85 s | posisi x = -0.477 meter
# t = 4.90 s | posisi x = -0.498 meter
# t = 4.95 s | posisi x = -0.495 meter
# t = 5.00 s | posisi x = -0.466 meter
# t = 5.05 s | posisi x = -0.415 meter
# t = 5.10 s | posisi x = -0.342 meter
# t = 5.15 s | posisi x = -0.253 meter
# t = 5.20 s | posisi x = -0.151 meter
# t = 5.25 s | posisi x = -0.042 meter
# t = 5.30 s | posisi x = 0.070 meter
# t = 5.35 s | posisi x = 0.178 meter
# t = 5.40 s | posisi x = 0.277 meter
# t = 5.45 s | posisi x = 0.363 meter
# t = 5.50 s | posisi x = 0.430 meter
# t = 5.55 s | posisi x = 0.476 meter
# t = 5.60 s | posisi x = 0.498 meter
# t = 5.65 s | posisi x = 0.495 meter
# t = 5.70 s | posisi x = 0.468 meter
# t = 5.75 s | posisi x = 0.418 meter
# t = 5.80 s | posisi x = 0.346 meter
# t = 5.85 s | posisi x = 0.258 meter
# t = 5.90 s | posisi x = 0.156 meter
# t = 5.95 s | posisi x = 0.047 meter
# t = 6.00 s | posisi x = -0.064 meter
# t = 6.05 s | posisi x = -0.173 meter
# t = 6.10 s | posisi x = -0.273 meter
# t = 6.15 s | posisi x = -0.359 meter
# t = 6.20 s | posisi x = -0.427 meter
# t = 6.25 s | posisi x = -0.474 meter
# t = 6.30 s | posisi x = -0.498 meter
# t = 6.35 s | posisi x = -0.496 meter
# t = 6.40 s | posisi x = -0.470 meter
# t = 6.45 s | posisi x = -0.421 meter
# t = 6.50 s | posisi x = -0.350 meter
# t = 6.55 s | posisi x = -0.262 meter
# t = 6.60 s | posisi x = -0.162 meter
# t = 6.65 s | posisi x = -0.053 meter
# t = 6.70 s | posisi x = 0.059 meter
# t = 6.75 s | posisi x = 0.168 meter
# t = 6.80 s | posisi x = 0.268 meter
# t = 6.85 s | posisi x = 0.355 meter
# t = 6.90 s | posisi x = 0.424 meter
# t = 6.95 s | posisi x = 0.472 meter
# t = 7.00 s | posisi x = 0.497 meter
# t = 7.05 s | posisi x = 0.497 meter
# t = 7.10 s | posisi x = 0.472 meter
# t = 7.15 s | posisi x = 0.424 meter
# t = 7.20 s | posisi x = 0.354 meter
# t = 7.25 s | posisi x = 0.267 meter
# t = 7.30 s | posisi x = 0.167 meter
# t = 7.35 s | posisi x = 0.058 meter
# t = 7.40 s | posisi x = -0.053 meter
# t = 7.45 s | posisi x = -0.162 meter
# t = 7.50 s | posisi x = -0.263 meter
# t = 7.55 s | posisi x = -0.351 meter
# t = 7.60 s | posisi x = -0.421 meter
# t = 7.65 s | posisi x = -0.470 meter
# t = 7.70 s | posisi x = -0.496 meter
# t = 7.75 s | posisi x = -0.497 meter
# t = 7.80 s | posisi x = -0.474 meter
# t = 7.85 s | posisi x = -0.427 meter
# t = 7.90 s | posisi x = -0.358 meter
# t = 7.95 s | posisi x = -0.272 meter
# t = 8.00 s | posisi x = -0.172 meter
# t = 8.05 s | posisi x = -0.064 meter
# t = 8.10 s | posisi x = 0.048 meter
# t = 8.15 s | posisi x = 0.157 meter
# t = 8.20 s | posisi x = 0.258 meter
# t = 8.25 s | posisi x = 0.347 meter
# t = 8.30 s | posisi x = 0.418 meter
# t = 8.35 s | posisi x = 0.469 meter
# t = 8.40 s | posisi x = 0.496 meter
# t = 8.45 s | posisi x = 0.498 meter
# t = 8.50 s | posisi x = 0.476 meter
# t = 8.55 s | posisi x = 0.429 meter
# t = 8.60 s | posisi x = 0.362 meter
# t = 8.65 s | posisi x = 0.276 meter
# t = 8.70 s | posisi x = 0.177 meter
# t = 8.75 s | posisi x = 0.069 meter
# t = 8.80 s | posisi x = -0.042 meter
# t = 8.85 s | posisi x = -0.152 meter
# t = 8.90 s | posisi x = -0.254 meter
# t = 8.95 s | posisi x = -0.343 meter
# t = 9.00 s | posisi x = -0.415 meter
# t = 9.05 s | posisi x = -0.467 meter
# t = 9.10 s | posisi x = -0.495 meter
# t = 9.15 s | posisi x = -0.498 meter
# t = 9.20 s | posisi x = -0.477 meter
# t = 9.25 s | posisi x = -0.432 meter
# t = 9.30 s | posisi x = -0.366 meter
# t = 9.35 s | posisi x = -0.281 meter
# t = 9.40 s | posisi x = -0.182 meter
# t = 9.45 s | posisi x = -0.075 meter
# t = 9.50 s | posisi x = 0.037 meter
# t = 9.55 s | posisi x = 0.147 meter
# t = 9.60 s | posisi x = 0.249 meter
# t = 9.65 s | posisi x = 0.339 meter
# t = 9.70 s | posisi x = 0.412 meter
# t = 9.75 s | posisi x = 0.465 meter
# t = 9.80 s | posisi x = 0.494 meter
# t = 9.85 s | posisi x = 0.499 meter
# t = 9.90 s | posisi x = 0.479 meter
# t = 9.95 s | posisi x = 0.435 meter
